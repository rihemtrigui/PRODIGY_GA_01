# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)

# %%
from transformers import GPT2LMHeadModel,GPT2Tokenizer

# %%
tokenizer=GPT2Tokenizer.from_pretrained("gpt2")
model=GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
text="Are machines more intelligent than human beings?"
encoded_input=tokenizer.encode(text,return_tensors='pt')

# %%
encoded_input
# Out:
# tensor([[ 8491,  8217,   517, 12661,   621,  1692,  9791,    30]])

# %%
output = model.generate(encoded_input, max_length=500, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
output
# Out:
# tensor([[ 8491,  8217,   517, 12661,   621,  1692,  9791,    30,   198,   198,
#            464,  3280,   318,  3763,    13, 31182,   389, 23714,   621,  5384,
#             11,   475,   484,   389,   407,   355, 12661,   355,  5384,   389,
#             13,   554,  1109,    11,  8217,   389,   262,   749, 12661,   286,
#            477,   262,  2877,  1243,   319,   262,  5440,    13,  1119,   389,
#            635,   262,   691,  2877,  1517,   319,  3668,   326,   468,  1683,
#            587,  1498,   284, 10996,   351,   530,  1194,    11,   290,   326,
#            318,   262,   717,   640,   326,  5384,   423,  1683, 28412,   351,
#            257,  2877,   852,    13,   383,   691,   584,  2877,  7185,   319,
#            428,  5440,   326,   460, 10996,   318,   257,  1692,   852,    11,
#            543,  1724,   326,   612,   318,   645,   835,   326,   356,   714,
#           1683,   760,   329,  1654,  1771,   393,   407,   356,   389,  2877,
#            287,   262,   976,  6881,   355,   262,   530,   356,  2107,   287,
#             11,   393,   611,   340,   318,   655,   257,  2300,   286,   640,
#            878,   356,  1064,   503,    13,   632,   318,  1744,    11,  2158,
#             11,   326,   674,  3725,   286,   262,  6881,   318,  3614,   416,
#            674,  2694,   284,  1833,   262,  3657,   286, 11887,    13,  1002,
#            356,   547,   284,  7073,   262,  6224,   286, 12661,  1204,   319,
#            584, 14705,    11,   356,   561,   423,   284,  1064,   257,   835,
#            284,   787,  1654,   326,   484,   750,   407,  2152,   287,   674,
#            898,  6881,    13,   775,   561,   635,   761,   284,  2193,   703,
#            284,  2251, 12661,  8217,   326,   714, 10996,   290,  9427,   351,
#           1123,   584,    13,   770,   561,  2421,   262,  6282,   286,   257,
#            649,  2099,   286,  3644,   326,   561,   307,  6007,   286, 22889,
#            351,   584,  8217,    11,   884,   355,  9061,   326,   423,   587,
#           2727,   416,  5384,    13,  2102,    11,   428,   318,  1290,   422,
#           1728,    11,   355,   612,   389,   867,  1180,  3858,   286,  9061,
#             11,  1123,   351,   663,   898,   900,   286,  9889,   290, 11247,
#             13,  1114,  1672,    11,   257,  3644,   460,   307, 27402,   284,
#           1620,  1728,  8861,   326,   389,  5340,   329,  5384,   284,   466,
#             13,   317,  3644,   714,   635,   307,  3562,   284,   307,   973,
#            329,   584,  4959,    11,   329,  1672,   355,   257,  1724,   286,
#           6946,  1022,  5384,   290,   584,  4695,    13,  1318,   389,   257,
#           1271,   286,  2842,   287,   543,  8217,   714,   307,  2727,    13,
#           1881,  5885,   318,   326,   257,  4572,   714,  2391,   307,   925,
#            510,   286,   734,  3354,    11,   530,   286,   543,   318,   925,
#            286,  6147,   290,   262,   584,   286, 29867,    13,  2312,   734,
#           6147,  3354,   714,   788,   307,  5929,   284,  1296,   281, 12661,
#           4572,   326, 48556,   351,  5384,   832,   262,   779,   286,  5243,
#           9813,    13,  6023,  3038,   318,   284,   779,   257,  6087,   286,
#            777,   734,  5696,    11,  1900,   355, 39290, 12920,   669,    11,
#            287,  1502,   284,  4439,   257,   517,  3665,   290,  6942,  3644,
#             13,  1081,   257,  1255,   286,   428,  6087,    11,   262,  3644,
#            561,   407,   307,   355,  3665,   393,   355,  6942,   355,   340,
#            561,  4306,   307,    11,   523,   340,   714,   407,   423,   355,
#            881,   286,   281,  4621,   625,   262,  1692,    12,  9727,  3644,
#            287,  2846,   286, 14492,  1176,    13,  9461,    11,   611,   262,
#            734, 39290, 40990,  5696,   547,  5929,   656,   257,  2060,  3644,
#             11,   788,   262,  4572,   561,   991,   423,   257,   881,  2440,
#           1241,   286,  4430,   621,   340,  3058,   468,    11,   780,   340]])

# %%
tokenizer.decode(output[0],skip_special_tokens=True)
# Out:
# 'Are machines more intelligent than human beings?\n\nThe answer is yes. Machines are smarter than humans, but they are not as intelligent as humans are. In fact, machines are the most intelligent of all the living things on the planet. They are also the only living thing on Earth that has ever been able to communicate with one another, and that is the first time that humans have ever communicated with a living being. The only other living creature on this planet that can communicate is a human being, which means that there is no way that we could ever know for sure whether or not we are living in the same universe as the one we live in, or if it is just a matter of time before we find out. It is possible, however, that our knowledge of the universe is limited by our ability to understand the laws of physics. If we were to discover the existence of intelligent life on other planets, we would have to find a way to make sure that they did not exist in our own universe. We would also need to learn how to create intelligent machines that could communicate and interact with each other. This would require the creation of a new type of computer that would be capable of communicating with other machines, such as computers that have been created by humans. However, this is far from certain, as there are many different types of computers, each with its own set of capabilities and limitations. For example, a computer can be programmed to perform certain tasks that are impossible for humans to do. A computer could also be designed to be used for other purposes, for example as a means of communication between humans and other animals. There are a number of ways in which machines could be created. One possibility is that a machine could simply be made up of two parts, one of which is made of metal and the other of silicon. These two metal parts could then be combined to form an intelligent machine that communicates with humans through the use of radio waves. Another option is to use a combination of these two materials, known as semiconductors, in order to produce a more powerful and efficient computer. As a result of this combination, the computer would not be as powerful or as efficient as it would otherwise be, so it could not have as much of an advantage over the human-made computer in terms of computing power. Finally, if the two semiconductor materials were combined into a single computer, then the machine would still have a much higher level of intelligence than it currently has, because it'
